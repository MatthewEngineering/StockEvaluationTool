# %%
import brel_main as mybrel

# %%
df = mybrel.get_presentation()
display(df)
# Out:
#                                                     0  \
# 0        us-gaap:StatementOfFinancialPositionAbstract
# 1                              us-gaap:AssetsAbstract
# 2       us-gaap:CashAndCashEquivalentsAtCarryingValue
# 3   v:RestrictedCashAndCashEquivalentsU.S.Litigati...
# 4                                 us-gaap:Investments
# 5                              v:SettlementReceivable
# 6                us-gaap:AccountsReceivableNetCurrent
# 7                          v:CustomerCollateralAssets
# 8                     v:ClientIncentivesAssetsCurrent
# 9         us-gaap:PrepaidExpenseAndOtherAssetsCurrent
# 10                              us-gaap:AssetsCurrent
# 11                        us-gaap:LongTermInvestments
# 12                 v:ClientIncentivesAssetsNoncurrent
# 13               us-gaap:PropertyPlantAndEquipmentNet
# 14                                   us-gaap:Goodwill
# 15       us-gaap:IntangibleAssetsNetExcludingGoodwill
# ...
